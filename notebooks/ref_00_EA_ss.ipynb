# %% [markdown]
# # Gas-phase Fractionation

# %%
from importlib import reload
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
DDA_evidence_1 = pd.read_csv('/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/MQ/combined/txt/evidence_1.txt',
                               sep='\t')
DDA_evidence_2 = pd.read_csv('/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/MQ/combined/txt/evidence_2.txt',
                               sep='\t')
DDA_evidence_3 = pd.read_csv('/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/MQ/combined/txt/evidence_3.txt',
                               sep='\t')
DDA_evidence_4 = pd.read_csv('/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/MQ/combined/txt/evidence_4.txt',
                               sep='\t')
DDA_evidence_5 = pd.read_csv('/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/MQ/combined/txt/evidence_5.txt',
                               sep='\t')

# %%
from matplotlib_venn import venn3
venn3([set(DDA_evidence_1["Modified sequence"].to_list()),
       set(DDA_evidence_2["Modified sequence"].to_list()),
       set(DDA_evidence_3["Modified sequence"].to_list())],
       #set(DDA_evidence_4["Modified sequence"].to_list())],
       #set(DDA_evidence_5["Modified sequence"].to_list())],
           set_labels=("1", "2", "3"))
