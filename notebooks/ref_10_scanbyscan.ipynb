# %%
from importlib import reload
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

import os
os.environ['NUMEXPR_MAX_THREADS'] = '32'
# %load_ext autoreload

# %%
import pickle
import sys

import numpy as np
import pandas as pd

module_path = os.path.abspath(
    "/mnt/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/")
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# path to the data input in mzML format, containing only MS1 level data
msconvert_file = "/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/raw/msconvert/BBM_647_P241_02_07_ssDDA_MIA_001.mzML"
# path to MaxQuant results (evidence.txt) of the same RAW file, used for constructing reference dictionary
maxquant_txt = "/mnt/cmnfs/proj/ORIGINS/data/protMSD/GCF_profile/combined/txt/evidence_transfer_RT_pred_filtered.txt"
# path to MaxQuant pickle file containing isotope pattern calculation
maxquant_file_dict = (
    "/mnt/cmnfs/proj/ORIGINS/data/ecoli/HpHRP/MQ/1FDR/"
    "combined/txt/evidence_1_FilteredByClosestRT_transfer_RT_pred_filtered_withIso.pkl"
)
maxquant_file_exp = (
    "/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/MQ/combined/txt/evidence_1.txt"
)

MS1Scans_NoArray_path = (
    "/mnt/cmnfs/proj/ORIGINS/data/ecoli/ss/DDA/raw/msconvert/"
    "BBM_647_P241_02_07_ssDDA_MIA_001_MS1Scans_NoArray.csv"
)

# %%
dirname = os.path.dirname(msconvert_file)
basename = os.path.basename(msconvert_file)
filename = basename[:-5] + "_ScanByScan"
# filename += '_isospec'+str(isospec)+'_dev'+str(dev)+'_initWithCos'+str(initWithCos)+'_IDwithCos'+str(IDwithCos)
print("Filename:", filename)
if not os.path.exists(os.path.join(dirname, filename)):
    os.makedirs(os.path.join(dirname, filename))
filename_full = os.path.join(dirname, filename)
insilico_file = os.path.join(filename_full, filename + "_insilico.xlsx")
output_file = os.path.join(filename_full, filename + "_output")  # filename
# Out:
# Filename: BBM_647_P241_02_07_ssDDA_MIA_001_ScanByScan

# %% [markdown]
# # Data Loading
# ## Load maxquant result

# %%
# with isotope pattern
try:
    Maxquant_result_dict = pd.read_pickle(filepath_or_buffer=maxquant_file_dict)
    logging.debug("Loaded maxquant result with isotope pattern.")
except FileNotFoundError:  # if not found, read txt and generate
    logging.info(
        "Maxquant result with isotope pattern not found, calculating from evidence.txt!"
    )
    Maxquant_result_dict = pd.read_csv(filepath_or_buffer=maxquant_txt, sep="\t")
    from optimization.dictionary import CalcModpeptIsopattern

    Maxquant_result_dict["IsoMZ"], Maxquant_result_dict["IsoAbundance"] = zip(
        *Maxquant_result_dict.apply(
            lambda row: CalcModpeptIsopattern(
                modpept=row["Modified sequence"], charge=row["Charge"], ab_thres=0.01
            ),
            axis=1,
        )
    )
    Maxquant_result_dict.columns
    Maxquant_result_dict.to_pickle(maxquant_file_dict)  # save pickle
# Out:
# 2023-12-06 17:01:12,567 - root - DEBUG - Loaded maxquant result with isotope pattern.

# %%
Maxquant_result_dict.columns
# Out:
# Index(['Sequence', 'Length', 'Modifications', 'Modified sequence',
#        'Oxidation (M) Probabilities', 'Oxidation (M) Score Diffs',
#        'Oxidation (M)', 'Missed cleavages', 'Proteins', 'Leading proteins',
#        'Leading razor protein', 'Gene names', 'Protein names', 'Type',
#        'Raw file', 'Fraction', 'Experiment', 'MS/MS m/z', 'Charge', 'm/z',
#        'Mass', 'Resolution', 'Uncalibrated - Calibrated m/z [ppm]',
#        'Uncalibrated - Calibrated m/z [Da]', 'Mass error [ppm]',
#        'Mass error [Da]', 'Uncalibrated mass error [ppm]',
#        'Uncalibrated mass error [Da]', 'Max intensity m/z 0', 'Retention time',
#        'Retention length', 'Calibrated retention time',
#        'Calibrated retention time start', 'Calibrated retention time finish',
#        'Retention time calibration', 'Match time difference',
#        'Match m/z difference', 'Match q-value', 'Match score',
#        'Number of data points', 'Number of scans', 'Number of isotopic peaks',
#        'PIF', 'Fraction of total spectrum', 'Base peak fraction', 'PEP',
#        'MS/MS count', 'Scan number', 'Score', 'Delta score', 'Combinatorics',
#        'Intensity', 'Reverse', 'Potential contaminant', 'id',
#        'Protein group IDs', 'Peptide ID', 'Mod. peptide ID', 'MS/MS IDs',
#        'Best MS/MS', 'AIF MS/MS IDs', 'Oxidation (M) site IDs', 'spec_id',
#        'peptide', 'modifications', 'charge', 'label',
#        'observed_retention_time', 'score', 'seq', 'tr', 'predicted_RT',
#        'RT_diff', 'IsoMZ', 'IsoAbundance'],
#       dtype='object')

# %% [markdown]
# ## Load MS1 scans

# %%
# from pkl or mzml file
from optimization.dictionary import LoadMZML

try:
    with open(msconvert_file[:-5] + ".pkl", "rb") as f:
        MS1Scans = pickle.load(f)
    print("Load pre-stored pickle results")
except:
    print("Pickle result not found, load mzml file.")
    MS1Scans = LoadMZML(msconvert_file)
    MS1Scans.to_pickle(msconvert_file[:-5] + ".pkl")
# Out:
# 2023-12-06 17:01:12,872 - matplotlib - DEBUG - matplotlib data path: /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data
# 2023-12-06 17:01:12,877 - matplotlib - DEBUG - CONFIGDIR=/home/zixuanxiao/.config/matplotlib
# 2023-12-06 17:01:12,878 - matplotlib - DEBUG - interactive is False
# 2023-12-06 17:01:12,878 - matplotlib - DEBUG - platform is linux
# 2023-12-06 17:01:12,913 - matplotlib - DEBUG - CACHEDIR=/home/zixuanxiao/.cache/matplotlib
# 2023-12-06 17:01:12,916 - matplotlib.font_manager - DEBUG - Using fontManager instance from /home/zixuanxiao/.cache/matplotlib/fontlist-v330.json
# Load pre-stored pickle results

# %%
MS1Scans["starttime"].describe()
MS1Scans_noarray = MS1Scans[["ind", "starttime"]]
# Out:
# count    2420.000000
# mean       16.186018
# std        11.102111
# min         0.002818
# 25%         5.630136
# 50%        16.010730
# 75%        26.384995
# max        33.001087
# Name: starttime, dtype: float64

# %% [markdown]
# ## Visualize Isotope Pattern

# %%
import result_analysis.result_analysis as RA
import result_analysis.result_analysis

reload(result_analysis.result_analysis)
# to compare the range of isotope pattern belonging to one precursor
RA.PlotIsoPatternsAndScan(
    MS1Scans=MS1Scans,
    Maxquant_result=Maxquant_result_dict,
    scan_idx=1748,
    precursor_id=[114498],
    log_intensity=False,
)
# to see peaks in a specific range
RA.PlotIsoPatternsAndScan(
    scan_idx=748,
    precursor_idx=None,
    mzrange=[509.75, 509.80],
    MS1Scans=MS1Scans,
    Maxquant_result=Maxquant_result_dict,
    log_intensity=False,
)
# Out:
# <module 'result_analysis.result_analysis' from '/mnt/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/result_analysis/result_analysis.py'>
# 2023-12-06 17:01:18,846 - matplotlib.pyplot - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2023-12-06 17:01:18,848 - matplotlib.pyplot - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2023-12-06 17:01:18,850 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 2023-12-06 17:01:18,851 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2023-12-06 17:01:18,851 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBol.ttf', name='STIXGeneral', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,852 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralItalic.ttf', name='STIXGeneral', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,852 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-BoldItalic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,852 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmsy10.ttf', name='cmsy10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,853 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmr10.ttf', name='cmr10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,853 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymReg.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,853 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneralBolIta.ttf', name='STIXGeneral', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,853 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymReg.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,854 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymReg.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,854 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUni.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,854 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFourSymBol.ttf', name='STIXSizeFourSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,854 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerifDisplay.ttf', name='DejaVu Serif Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,854 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBol.ttf', name='STIXNonUnicode', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,855 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Oblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,855 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizTwoSymBol.ttf', name='STIXSizeTwoSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,855 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,855 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,855 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmss10.ttf', name='cmss10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,856 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmb10.ttf', name='cmb10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,856 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,857 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Oblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 1.05
# 2023-12-06 17:01:18,857 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXGeneral.ttf', name='STIXGeneral', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,858 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmmi10.ttf', name='cmmi10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,859 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizOneSymBol.ttf', name='STIXSizeOneSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,859 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymBol.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,859 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Italic.ttf', name='DejaVu Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,860 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,860 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-BoldOblique.ttf', name='DejaVu Sans', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 1.335
# 2023-12-06 17:01:18,862 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizFiveSymReg.ttf', name='STIXSizeFiveSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,862 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansDisplay.ttf', name='DejaVu Sans Display', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,863 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmex10.ttf', name='cmex10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,863 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXSizThreeSymReg.ttf', name='STIXSizeThreeSym', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,863 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/cmtt10.ttf', name='cmtt10', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,863 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono-BoldOblique.ttf', name='DejaVu Sans Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,864 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,864 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2023-12-06 17:01:18,864 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/STIXNonUniBolIta.ttf', name='STIXNonUnicode', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,865 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/noto/NotoSerifCJK-Bold.ttc', name='Noto Serif CJK JP', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,865 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Regular.ttf', name='Liberation Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,865 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgMono-BoldOblique.ttf', name='Tlwg Mono', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,866 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,866 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Loma-Bold.ttf', name='Loma', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,867 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-SemiBold.ttf', name='Yrsa', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2023-12-06 17:01:18,868 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/AnjaliOldLipi-Regular.ttf', name='AnjaliOldLipi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,869 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Rasa-Light.ttf', name='Rasa', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,869 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/Gurajada.ttf', name='Gurajada', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,870 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWBookman-LightItalic.otf', name='URW Bookman', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2023-12-06 17:01:18,870 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Italic.otf', name='Nimbus Mono PS', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,870 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,871 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/SreeKrushnadevaraya.ttf', name='Sree Krushnadevaraya', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,871 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/padauk/Padauk-Bold.ttf', name='Padauk', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,871 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,872 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgMono-Bold.ttf', name='Tlwg Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,872 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Regular.otf', name='Gayathri', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,872 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/mallanna.ttf', name='Mallanna', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,873 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstBook.ttf', name='KacstBook', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,873 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-BoldItalic.ttf', name='Yrsa', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,873 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Italic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,874 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Rasa-Regular.ttf', name='Rasa', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,874 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Bold.otf', name='Nimbus Sans Narrow', style='normal', variant='normal', weight=700, stretch='condensed', size='scalable')) = 10.535
# 2023-12-06 17:01:18,874 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf', name='Liberation Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,874 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstFarsi.ttf', name='KacstFarsi', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,874 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi-BoldItalic.ttf', name='Norasi', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,875 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-bengali/Lohit-Bengali.ttf', name='Lohit Bengali', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,875 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstTitle.ttf', name='KacstTitle', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,875 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypo-Oblique.ttf', name='Tlwg Typo', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,875 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Nakula/nakula.ttf', name='Nakula', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,876 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerifItalic.ttf', name='FreeSerif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,876 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/MitraMono.ttf', name='Mitra ', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,876 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist-Bold.ttf', name='Tlwg Typist', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,877 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/samanata.ttf', name='Samanata', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,877 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstDecorative.ttf', name='KacstDecorative', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,877 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Laksaman-Italic.ttf', name='Laksaman', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,880 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/TimmanaRegular.ttf', name='Timmana', style='normal', variant='normal', weight=900, stretch='normal', size='scalable')) = 10.525
# 2023-12-06 17:01:18,881 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-guru-extra/Saab.ttf', name='Saab', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,881 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstPoster.ttf', name='KacstPoster', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,881 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Italic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,882 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/kalimati.ttf', name='Kalimati', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,882 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Purisa.ttf', name='Purisa', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,882 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/suranna.ttf', name='Suranna', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,882 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-deva-extra/chandas1-2.ttf', name='Chandas', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,883 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Regular.otf', name='Nimbus Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,883 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda-BoldOblique.ttf', name='Garuda', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,883 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-BoldItalic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,884 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-tamil-classical/Lohit-Tamil-Classical.ttf', name='Lohit Tamil Classical', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,885 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/sinhala/lklug.ttf', name='LKLUG', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,885 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-M.ttf', name='Ubuntu', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,885 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Navilu/Navilu.ttf', name='Navilu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,886 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda.ttf', name='Garuda', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,886 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Bold.otf', name='Gayathri', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,886 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Loma-BoldOblique.ttf', name='Loma', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,886 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/samyak/Samyak-Devanagari.ttf', name='Samyak Devanagari', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,887 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-malayalam/Lohit-Malayalam.ttf', name='Lohit Malayalam', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,888 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-BI.ttf', name='Ubuntu Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,888 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstNaskh.ttf', name='KacstNaskh', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,888 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusRoman-Regular.otf', name='Nimbus Roman', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,889 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypewriter-Oblique.ttf', name='Tlwg Typewriter', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,890 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-DemiOblique.otf', name='URW Gothic', style='oblique', variant='normal', weight=600, stretch='normal', size='scalable')) = 11.24
# 2023-12-06 17:01:18,890 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 0.33499999999999996
# 2023-12-06 17:01:18,890 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf', name='DejaVu Sans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 0.05
# 2023-12-06 17:01:18,891 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi-Bold.ttf', name='Norasi', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,891 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', name='DejaVu Sans Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,891 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi.ttf', name='Norasi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,892 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/NATS.ttf', name='NATS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,892 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Umpush-Light.ttf', name='Umpush', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,892 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-BoldItalic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,892 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-BoldItalic.otf', name='Nimbus Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,893 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-Th.ttf', name='Ubuntu', style='normal', variant='normal', weight=250, stretch='normal', size='scalable')) = 10.1925
# 2023-12-06 17:01:18,893 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-B.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,893 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Norasi-BoldOblique.ttf', name='Norasi', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,894 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-orya-extra/utkal.ttf', name='ori1Uni', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,894 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/noto/NotoSansCJK-Regular.ttc', name='Noto Sans CJK JP', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,895 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSans-Bold.otf', name='Nimbus Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,895 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-Bold.ttf', name='Kinnari', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,896 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist-Oblique.ttf', name='Tlwg Typist', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,896 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Regular.ttf', name='Yrsa', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,897 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst-one/KacstOne.ttf', name='KacstOne', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,897 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-punjabi/Lohit-Gurmukhi.ttf', name='Lohit Gurmukhi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,897 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSerif.ttf', name='FreeSerif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,898 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-RI.ttf', name='Ubuntu', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,898 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSans.ttf', name='FreeSans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,898 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/UbuntuMono-R.ttf', name='Ubuntu Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,899 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf', name='Liberation Sans Narrow', style='italic', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2023-12-06 17:01:18,899 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-Roman.otf', name='P052', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,899 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Karumbi-Regular.ttf', name='Karumbi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,900 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Light.ttf', name='Yrsa', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,900 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-Demi.otf', name='URW Gothic', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2023-12-06 17:01:18,900 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/dhurjati.ttf', name='Dhurjati', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,901 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Uroob-Regular.ttf', name='Uroob', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,901 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf', name='Liberation Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,901 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-BoldItalic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,902 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Garuda-Bold.ttf', name='Garuda', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,902 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-BookOblique.otf', name='URW Gothic', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,902 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Gubbi/Gubbi.ttf', name='Gubbi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,903 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Sawasdee-Bold.ttf', name='Sawasdee', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,903 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-gujr-extra/padmaa-Medium-0.5.ttf', name='padmaa', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,903 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSerif-Regular.ttf', name='Liberation Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,904 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypewriter-Bold.ttf', name='Tlwg Typewriter', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,904 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Sawasdee-BoldOblique.ttf', name='Sawasdee', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,905 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/noto/NotoSansCJK-Bold.ttc', name='Noto Sans CJK JP', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,905 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSans-Bold.ttf', name='Liberation Sans', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,905 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-Bold.otf', name='C059', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,906 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/noto/NotoSerifCJK-Regular.ttc', name='Noto Serif CJK JP', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,906 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Laksaman-Bold.ttf', name='Laksaman', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,907 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Chilanka-Regular.otf', name='Chilanka', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,907 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Umpush.ttf', name='Umpush', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,908 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/padauk/PadaukBook-Regular.ttf', name='Padauk Book', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,908 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Rasa-Bold.ttf', name='Rasa', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,908 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansOblique.ttf', name='FreeSans', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,909 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Waree-Oblique.ttf', name='Waree', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,909 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/Mukti.ttf', name='Mukti', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,909 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstArt.ttf', name='KacstArt', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,910 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-telugu/Lohit-Telugu.ttf', name='Lohit Telugu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,910 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Regular.otf', name='Nimbus Mono PS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,910 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-gujr-extra/aakar-medium.ttf', name='aakar', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:18,910 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-Italic.otf', name='C059', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:18,911 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/Gidugu.ttf', name='Gidugu', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,911 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/ramabhadra.ttf', name='Ramabhadra', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,911 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-Bold.ttf', name='Liberation Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,914 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/P052-BoldItalic.otf', name='P052', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,914 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-tamil/Lohit-Tamil.ttf', name='Lohit Tamil', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,914 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Manjari-Thin.otf', name='Manjari', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,915 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/libreoffice/opens___.ttf', name='OpenSymbol', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,915 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-khmeros-core/KhmerOS.ttf', name='Khmer OS', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,915 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/Ramaraja-Regular.ttf', name='Ramaraja', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,916 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-assamese/Lohit-Assamese.ttf', name='Lohit Assamese', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,916 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationMono-Bold.ttf', name='Liberation Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,916 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-BoldItalic.ttf', name='Kinnari', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,917 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-BdIta.otf', name='C059', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:18,918 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-oriya/Lohit-Odia.ttf', name='Lohit Odia', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:18,919 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf', name='Liberation Mono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:18,919 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Rasa-Medium.ttf', name='Rasa', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# ...
# 2023-12-06 17:01:19,153 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lohit-devanagari/Lohit-Devanagari.ttf', name='Lohit Devanagari', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,154 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/SyamalaRamana.ttf', name='Syamala Ramana', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,154 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoOblique.ttf', name='FreeMono', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:19,154 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusMonoPS-Bold.otf', name='Nimbus Mono PS', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,154 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif-Bold.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,155 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-Oblique.ttf', name='Kinnari', style='oblique', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:19,155 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ttf-khmeros-core/KhmerOSsys.ttf', name='Khmer OS System', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,155 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeMonoBold.ttf', name='FreeMono', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,156 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Gayathri-Thin.otf', name='Gayathri', style='normal', variant='normal', weight=100, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,158 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/lao/Phetsarath_OT.ttf', name='Phetsarath OT', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,159 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/noto/NotoMono-Regular.ttf', name='Noto Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,162 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/C059-Roman.otf', name='C059', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,166 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Umpush-LightOblique.ttf', name='Umpush', style='oblique', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2023-12-06 17:01:19,168 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-B.ttf', name='Ubuntu', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,169 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypewriter-BoldOblique.ttf', name='Tlwg Typewriter', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,170 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/TenaliRamakrishna-Regular.ttf', name='TenaliRamakrishna', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,170 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Umpush-BoldOblique.ttf', name='Umpush', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,171 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-BoldOblique.ttf', name='Kinnari', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,171 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist.ttf', name='Tlwg Typist', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,171 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation2/LiberationSerif-Italic.ttf', name='Liberation Serif', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:19,172 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/RaviPrakash.ttf', name='RaviPrakash', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,172 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-L.ttf', name='Ubuntu', style='normal', variant='normal', weight=300, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:19,172 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusRoman-Italic.otf', name='Nimbus Roman', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:19,172 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/dejavu/DejaVuSerif.ttf', name='DejaVu Serif', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,173 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Waree-BoldOblique.ttf', name='Waree', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,173 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgMono.ttf', name='Tlwg Mono', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,173 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/RaghuMalayalamSans-Regular.ttf', name='RaghuMalayalamSans', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,174 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Medium.ttf', name='Yrsa', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:19,174 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstLetter.ttf', name='KacstLetter', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:19,174 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/Ani.ttf', name='Ani', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,175 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/URWGothic-Book.otf', name='URW Gothic', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,175 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationSans-BoldItalic.ttf', name='Liberation Sans', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,175 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypo.ttf', name='Tlwg Typo', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,176 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Kinnari-Italic.ttf', name='Kinnari', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:19,176 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Meera-Regular.ttf', name='Meera', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,177 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Umpush-Bold.ttf', name='Umpush', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,181 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-telu-extra/vemana2000.ttf', name='Vemana2000', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,183 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/freefont/FreeSansBold.ttf', name='FreeSans', style='normal', variant='normal', weight=600, stretch='normal', size='scalable')) = 10.24
# 2023-12-06 17:01:19,183 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/NTR.ttf', name='NTR', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,184 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypo-Bold.ttf', name='Tlwg Typo', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,184 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/malayalam/Manjari-Bold.otf', name='Manjari', style='normal', variant='normal', weight=700, stretch='normal', size='scalable')) = 10.335
# 2023-12-06 17:01:19,185 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-beng-extra/JamrulNormal.ttf', name='Jamrul', style='normal', variant='normal', weight=500, stretch='normal', size='scalable')) = 10.145
# 2023-12-06 17:01:19,185 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-C.ttf', name='Ubuntu Condensed', style='normal', variant='normal', weight=400, stretch='condensed', size='scalable')) = 10.25
# 2023-12-06 17:01:19,186 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/Peddana-Regular.ttf', name='Peddana', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,186 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Dyuthi-Regular.ttf', name='Dyuthi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,187 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/opentype/urw-base35/NimbusSansNarrow-Oblique.otf', name='Nimbus Sans Narrow', style='oblique', variant='normal', weight=400, stretch='condensed', size='scalable')) = 11.25
# 2023-12-06 17:01:19,187 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/ubuntu/Ubuntu-LI.ttf', name='Ubuntu', style='italic', variant='normal', weight=300, stretch='normal', size='scalable')) = 11.145
# 2023-12-06 17:01:19,188 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Purisa-BoldOblique.ttf', name='Purisa', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,188 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypewriter.ttf', name='Tlwg Typewriter', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,189 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Sawasdee.ttf', name='Sawasdee', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,190 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Loma.ttf', name='Loma', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,190 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/TlwgTypist-BoldOblique.ttf', name='Tlwg Typist', style='oblique', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,190 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/fonts-yrsa-rasa/Yrsa-Italic.ttf', name='Yrsa', style='italic', variant='normal', weight=400, stretch='normal', size='scalable')) = 11.05
# 2023-12-06 17:01:19,191 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/tlwg/Laksaman.ttf', name='Laksaman', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,191 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/teluguvijayam/LakkiReddy.ttf', name='LakkiReddy', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,192 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/kacst/KacstQurn.ttf', name='KacstQurn', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,192 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/malayalam/Rachana-Regular.ttf', name='Rachana', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,193 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/Gargi/Gargi.ttf', name='Gargi', style='normal', variant='normal', weight=400, stretch='normal', size='scalable')) = 10.05
# 2023-12-06 17:01:19,193 - matplotlib.font_manager - DEBUG - findfont: score(FontEntry(fname='/usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf', name='Liberation Mono', style='italic', variant='normal', weight=700, stretch='normal', size='scalable')) = 11.335
# 2023-12-06 17:01:19,193 - matplotlib.font_manager - DEBUG - findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=12.0 to DejaVu Sans ('/home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000.
# Peak results:
#    apex_mzidx     apex_mz  start_mzidx    start_mz  end_mzidx      end_mz  \
# 0           6  509.773383            4  509.766475          9  509.783745
#
#    peak_width   peak_height  peak_intensity_sum
# 0     0.01727  210815.90625        2.940859e+06

# %% [markdown]
# # ID and Qunat

# %% [markdown]
# ## One Scan

# %%
# %autoreload 2
from result_analysis import result_analysis
from optimization.inference import process_one_scan, Quant
scan_idx =947
RT_tol = 1.0
RT_ref = 'pred'                            
# example: generate dictionary for candidate in one scan
OneScan = MS1Scans.iloc[scan_idx, :]
# Set left and right edge for scan search range
if RT_ref == 'exp':
    Maxquant_result_dict['RT_search_left'] = Maxquant_result_dict['Calibrated retention time start'] - RT_tol
    Maxquant_result_dict['RT_search_right'] = Maxquant_result_dict['Calibrated retention time finish'] + RT_tol
elif RT_ref == 'pred':
    Maxquant_result_dict['RT_search_left'] = Maxquant_result_dict['predicted_RT'] - RT_tol
    Maxquant_result_dict['RT_search_right'] = Maxquant_result_dict['predicted_RT'] + RT_tol
elif RT_ref == 'mix':
    Maxquant_result_dict['RT_search_left'] = Maxquant_result_dict['Retention time new'] - RT_tol
    Maxquant_result_dict['RT_search_right'] = Maxquant_result_dict['Retention time new'] + RT_tol
scan_result, scan_dict, Quant = process_one_scan(scan_idx=scan_idx,
                                AbundanceMissingThres=0.3, 
                                OneScan=OneScan,
                                loss = 'lasso',
                                alpha_criteria = 'min',
                                alphas=[0],
                                metric='RMSE',
                                opt_algo= 'threshold',
                                Maxquant_result=Maxquant_result_dict, 
                                preprocessing_method='raw',
                                max_iter=250,
                                corr_thres=0.97,
                                return_interim_results=True,
                                return_precusor_scan_cos_dist=True,
                                plot_alpha_trace=False,
                                plot_obs_and_infer=True)
# Out:
# 2023-12-06 17:10:09,114 - optimization.inference - DEBUG - Start.
# 2023-12-06 17:10:09,137 - optimization.inference - DEBUG - Filter by RT.
# 2023-12-06 17:10:09,139 - optimization.dictionary - INFO - Number of candidates by RT 4448
# 2023-12-06 17:10:09,182 - optimization.dictionary - INFO - Number of candidates after isotope match 1821
# 2023-12-06 17:10:09,184 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 371
# 2023-12-06 17:10:09,231 - optimization.dictionary - DEBUG - [Double check] Number of candidates by RT and abundance filter 371
# 2023-12-06 17:10:09,412 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.97: 200
# 2023-12-06 17:10:09,415 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 222
# 2023-12-06 17:10:09,415 - optimization.inference - DEBUG - Construct dictionary
# 2023-12-06 17:10:09,416 - optimization.inference - DEBUG - obs mz (index) dimension: (926,)
# 2023-12-06 17:10:09,420 - optimization.inference - DEBUG - dimension of act: (1, 371)
# 2023-12-06 17:10:09,421 - optimization.inference - DEBUG - dimension of act: (1, 371)
# 2023-12-06 17:10:09,422 - optimization.inference - INFO - Minimal distance reached at alpha = 0
# 2023-12-06 17:10:09,422 - optimization.inference - DEBUG - Quant - optimize alphas
# 2023-12-06 17:10:09,480 - optimization.inference - DEBUG - Quant - Plot
# 2023-12-06 17:10:09,508 - optimization.inference - INFO - scan index 947: activation successfully calculated with cosine distance 0.20212806278073703, RMSE 68000548.90818477.

# %%
a = pd.DataFrame(scan_result[scan_idx]["activation"])
a[a["precursor"] == 44321]
# Out:
#     precursor    activation
# 80      44321  2.972822e+06

# %%
Quant.plot_iso_pattern_and_infer(
    Maxquant_result=Maxquant_result_dict, precursor_id=[44321], log_intensity=False
)
# Out:
# 2023-11-22 14:27:03,623 - result_analysis.result_analysis - DEBUG - infer m/z and intensities: Float64Index([688.798643127982, 689.2980074464168], dtype='float64'), [0. 0.]
# Isotope Pattern: 14213 [688.800408   689.29892545 689.30208542 689.80060287 689.8025305
#  689.80376284 690.30420792 690.30544025] [0.49150318 0.03054204 0.28409012 0.01765338 0.02627883 0.08055331
#  0.01518923 0.01493435]

# %%
dict = scan_dict.dict

# %%
from optimization.dictionary import Dict
import optimization.dictionary

reload(optimization.dictionary)
CandidatePrecursorsByRT = Maxquant_result_dict.loc[
    (Maxquant_result_dict["RT_search_left"] <= OneScan["starttime"])
    & (Maxquant_result_dict["RT_search_right"] >= OneScan["starttime"])
]
ScanDict = Dict(
    CandidateByRT=CandidatePrecursorsByRT, OneScan=OneScan, AbundanceMissingThres=0.3
)
ScanDict.plot_observe_iso_abundance()
# Out:
# <module 'optimization.dictionary' from '/mnt/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/optimization/dictionary.py'>
# 2023-11-22 13:25:32,210 - optimization.dictionary - INFO - Number of candidates by RT 3272
# 2023-11-22 13:25:32,247 - optimization.dictionary - INFO - Number of candidates after isotope match 1192
# 2023-11-22 13:25:32,248 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 242
# 2023-11-22 13:25:32,278 - optimization.dictionary - DEBUG - [Double check] Number of candidates by RT and abundance filter 242

# %%
# %matplotlib inline
ScanDict.get_feature_corr(corr_thres=0.95, plot_hist=False)
# Out:
# 2023-11-21 13:33:50,617 - matplotlib.pyplot - DEBUG - Loaded backend module://matplotlib_inline.backend_inline version unknown.
# 2023-11-21 13:33:51,211 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 141
# 2023-11-21 13:33:51,212 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 161

# %%
import result_analysis.result_analysis as RA
import result_analysis.result_analysis

reload(result_analysis.result_analysis)
# to see peaks in a specific range
RA.PlotIsoPatternsAndScan(
    scan_idx=1008,
    precursor_idx=[3614, 14909],
    mzrange=None,
    MS1Scans=MS1Scans,
    Maxquant_result=Maxquant_result_dict,
    log_intensity=False,
)
# Out:
# <module 'result_analysis.result_analysis' from '/mnt/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/result_analysis/result_analysis.py'>
# Peak results:
#      apex_mzidx     apex_mz  start_mzidx    start_mz  end_mzidx      end_mz  \
# 0             8  600.296767            5  600.283526         10  600.305595
# 1            26  600.631228           23  600.617976         28  600.640063
# 2            42  600.962982           40  600.954140         45  600.976246
# 3            58  601.259327           56  601.250478         61  601.272600
# 4            66  601.294723           63  601.281449         69  601.307997
# ..          ...         ...          ...         ...        ...         ...
# 288        4273  985.599337         4271  985.580766       4276  985.627194
# 289        4291  986.602845         4289  986.584246       4294  986.630745
# 290        4307  987.608364         4304  987.580423       4309  987.626993
# 291        4322  992.507007         4319  992.478857       4324  992.525774
# 292        4336  993.502385         4334  993.483590       4339  993.531192
#
#      peak_width   peak_height  peak_intensity_sum
# 0      0.022068  1.189274e+06        1.762589e+07
# 1      0.022087  1.219460e+06        1.892435e+07
# 2      0.022105  5.388360e+05        8.041617e+06
# 3      0.022122  2.914257e+05        3.956444e+06
# 4      0.026548  2.541445e+05        4.555758e+06
# ..          ...           ...                 ...
# 288    0.046428  1.730746e+06        2.532649e+07
# 289    0.046499  7.709901e+05        1.114967e+07
# 290    0.046569  2.543374e+05        4.072327e+06
# 291    0.046916  3.247162e+05        4.857222e+06
# 292    0.047602  1.600004e+05        2.367458e+06
#
# [293 rows x 9 columns]
# Isotope Pattern: 3614 [600.30346397 600.5527227  600.55430268 600.80356141 600.80452522
#  600.80514139 601.05440011 601.05536393 601.0559801  601.30620264
#  601.30681881] [0.25794706 0.03017195 0.29537505 0.03454988 0.01750454 0.16750627
#  0.01959313 0.02004444 0.06271927 0.01136714 0.01744195]
# Isotope Pattern: 14909 [994.45421604 994.95273348 994.95589345 995.45211397 995.4544109
#  995.45633853 995.45757087 995.95379138 995.95608832 995.95801595
#  995.95924829 996.4554688 ] [0.30572954 0.02682078 0.28007259 0.02737233 0.02456997 0.01760361
#  0.1267572  0.02507523 0.01112005 0.01612631 0.03778498 0.01134872]

# %% [markdown]
# ### Explore Isotope Pattern between Sequence

# %%
import IsoSpecPy as iso

pair = [4129, 6698]
Maxquant_result_dict.loc[
    pair, ["Modified sequence", "Charge", "Retention time", "Intensity", "m/z"]
]
iso.ParseFASTA(Maxquant_result_dict.loc[pair[0], "Modified sequence"])
iso.ParseFASTA(Maxquant_result_dict.loc[pair[1], "Modified sequence"])
# Out:
#           Modified sequence  Charge  Retention time    Intensity          m/z
# 4129     _ANGANTVIGPLNWDEK_       2          21.400   14850000.0   849.925926
# 6698  _CVDTSMGLTPLEGLVMGTR_       2          29.274  124510000.0  1018.994310
# OrderedDict([('C', 74), ('H', 113), ('N', 21), ('O', 24), ('S', 0)])
# OrderedDict([('C', 82), ('H', 140), ('N', 22), ('O', 27), ('S', 3)])

# %%
from optimization.dictionary import CalcModpeptIsopattern

CalcModpeptIsopattern(modpept="_EKVEGTIDK_", charge=2, ab_thres=0.001)
# Out:
# (array([509.77494504, 510.27346248, 510.27662245, 510.27705361,
#         510.27808341, 510.7751399 , 510.77706753, 510.77829987,
#         510.77873102, 510.77976083, 511.27681732, 511.27874495,
#         511.27997729, 511.78042237, 511.78165471]),
#  array([0.57300948, 0.02303972, 0.26871023, 0.00372042, 0.00510591,
#         0.01080438, 0.02003166, 0.06153999, 0.00174467, 0.00239439,
#         0.00247442, 0.00939376, 0.00917221, 0.00215136, 0.00100029]))

# %% [markdown]
# ## Batch Scan Processing

# %%
# %autoreload 2
from optimization.inference import process_scans_parallel, process_one_scan
from multiprocessing import cpu_count
import optimization.inference

reload(optimization.inference)
RT_ref == "mix"
RT_tol = 1.0
# Set left and right edge for scan search range
if RT_ref == "exp":
    Maxquant_result_dict["RT_search_left"] = (
        Maxquant_result_dict["Calibrated retention time start"] - RT_tol
    )
    Maxquant_result_dict["RT_search_right"] = (
        Maxquant_result_dict["Calibrated retention time finish"] + RT_tol
    )
elif RT_ref == "pred":
    Maxquant_result_dict["RT_search_left"] = (
        Maxquant_result_dict["predicted_RT"] - RT_tol
    )
    Maxquant_result_dict["RT_search_right"] = (
        Maxquant_result_dict["predicted_RT"] + RT_tol
    )
elif RT_ref == "mix":
    Maxquant_result_dict["RT_search_left"] = (
        Maxquant_result_dict["Retention time new"] - RT_tol
    )
    Maxquant_result_dict["RT_search_right"] = (
        Maxquant_result_dict["Retention time new"] + RT_tol
    )
result_dict = process_scans_parallel(
    n_jobs=cpu_count(),
    alphas=[0, 100, 1000, 10000, 100000, 1000000],
    AbundanceMissingThres=1.0,
    # for small scale testing: MS1Scans.iloc[1000:1050, :]
    MS1Scans=MS1Scans.iloc[638:646, :],
    Maxquant_result=Maxquant_result_dict,
    preprocessing_method="raw",
    loss="lasso",
    opt_algo="threshold",
    return_precursor_scan_cos_dist=True,
)
# Out:
# <module 'optimization.inference' from '/mnt/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/optimization/inference.py'>
# False
# 2023-12-06 17:15:44,431 - optimization.dictionary - INFO - Number of candidates by RT 3300
# 2023-12-06 17:15:44,470 - optimization.dictionary - INFO - Number of candidates after isotope match 1488
# 2023-12-06 17:15:44,471 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1488
# 2023-12-06 17:15:46,073 - optimization.dictionary - INFO - Number of candidates by RT 3296
# 2023-12-06 17:15:46,118 - optimization.dictionary - INFO - Number of candidates after isotope match 1440
# 2023-12-06 17:15:46,118 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1440
# 2023-12-06 17:15:47,984 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 105334
# 2023-12-06 17:15:47,991 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 1112
# 2023-12-06 17:15:48,019 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:15:48,940 - optimization.inference - INFO - scan index 638: activation successfully calculated with cosine distance 0.782717733378619, RMSE 125091131.22589418.
# 2023-12-06 17:15:49,146 - optimization.dictionary - INFO - Number of candidates by RT 3280
# 2023-12-06 17:15:49,189 - optimization.dictionary - INFO - Number of candidates after isotope match 1300
# 2023-12-06 17:15:49,189 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1300
# 2023-12-06 17:15:49,387 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 121491
# 2023-12-06 17:15:49,391 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 1079
# 2023-12-06 17:15:49,413 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:15:49,936 - optimization.inference - INFO - scan index 639: activation successfully calculated with cosine distance 0.8610145832511514, RMSE 158792765.51939967.
# 2023-12-06 17:15:51,577 - optimization.dictionary - INFO - Number of candidates by RT 3271
# 2023-12-06 17:15:51,626 - optimization.dictionary - INFO - Number of candidates after isotope match 1311
# 2023-12-06 17:15:51,627 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1311
# 2023-12-06 17:15:51,768 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 105556
# 2023-12-06 17:15:51,771 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 968
# 2023-12-06 17:15:51,784 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:15:52,072 - optimization.inference - INFO - scan index 640: activation successfully calculated with cosine distance 0.782408857786181, RMSE 177217327.42332637.
# 2023-12-06 17:15:53,363 - optimization.dictionary - INFO - Number of candidates by RT 3269
# 2023-12-06 17:15:53,408 - optimization.dictionary - INFO - Number of candidates after isotope match 1172
# 2023-12-06 17:15:53,408 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1172
# 2023-12-06 17:15:54,022 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 95119
# 2023-12-06 17:15:54,027 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 989
# 2023-12-06 17:15:54,043 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:15:54,373 - optimization.inference - INFO - scan index 641: activation successfully calculated with cosine distance 0.4553156013292481, RMSE 242654178.83184433.
# 2023-12-06 17:15:55,249 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 77307
# 2023-12-06 17:15:55,253 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 908
# 2023-12-06 17:15:55,267 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:15:55,463 - optimization.inference - INFO - scan index 642: activation successfully calculated with cosine distance 0.2820022159439357, RMSE 349084329.8084325.
# 2023-12-06 17:15:56,112 - optimization.dictionary - INFO - Number of candidates by RT 3275
# 2023-12-06 17:15:56,158 - optimization.dictionary - INFO - Number of candidates after isotope match 1152
# 2023-12-06 17:15:56,159 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1152
# 2023-12-06 17:15:57,749 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 81977
# 2023-12-06 17:15:57,752 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 882
# 2023-12-06 17:15:57,765 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:15:57,956 - optimization.inference - INFO - scan index 643: activation successfully calculated with cosine distance 0.24126337910465, RMSE 402271732.7584687.
# 2023-12-06 17:15:58,048 - optimization.dictionary - INFO - Number of candidates by RT 3271
# 2023-12-06 17:15:58,089 - optimization.dictionary - INFO - Number of candidates after isotope match 1147
# 2023-12-06 17:15:58,090 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1147
# 2023-12-06 17:15:59,672 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 82935
# 2023-12-06 17:15:59,678 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 886
# 2023-12-06 17:15:59,688 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:15:59,856 - optimization.inference - INFO - scan index 644: activation successfully calculated with cosine distance 0.2779101286817466, RMSE 311954036.88219553.
# 2023-12-06 17:16:00,237 - optimization.dictionary - INFO - Number of candidates by RT 3261
# 2023-12-06 17:16:00,269 - optimization.dictionary - INFO - Number of candidates after isotope match 1059
# 2023-12-06 17:16:00,270 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 1059
# 2023-12-06 17:16:01,506 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 62507
# 2023-12-06 17:16:01,509 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 803
# 2023-12-06 17:16:01,517 - optimization.inference - INFO - Reached convergence criteria at alpha = 100
# 2023-12-06 17:16:01,646 - optimization.inference - INFO - scan index 645: activation successfully calculated with cosine distance 0.42275691206976074, RMSE 281050558.89547.

# %%
# merge results
n_ms1scans = MS1Scans.shape[0]
activation = pd.DataFrame(index=Maxquant_result_dict["id"], columns=range(n_ms1scans))
scan_record_list = []
# scan_alignments = {}
for scan_idx, result_dict_scan in result_dict.items():
    if result_dict_scan["activation"] is not None:
        activation.loc[
            result_dict_scan["activation"]["precursor"], scan_idx
        ] = result_dict_scan["activation"]["activation"]
    scan_record_list.append(result_dict_scan["scans_record"])
    # scan_alignments[scan_idx] = result_dict_scan['alignment']
scan_record = pd.DataFrame(
    scan_record_list,
    columns=[
        "Scan",
        "Time",
        "CandidatePrecursorByRT",
        "FilteredPrecursor",
        "NumberHighlyCorrDictCandidate",
        "BestAlpha",
        "Cosine Dist",
        "IntensityExplained",
    ],
)

# %%
a = activation.loc[:, 638:646]

# %%
from optimization.inference import process_scans_parallel
from multiprocessing import cpu_count
import optimization.inference

reload(optimization.inference)
RT_ref == "exp"
RT_tol = 1.0
# Set left and right edge for scan search range
if RT_ref == "exp":
    Maxquant_result_dict["RT_search_left"] = (
        Maxquant_result_dict["Calibrated retention time start"] - RT_tol
    )
    Maxquant_result_dict["RT_search_right"] = (
        Maxquant_result_dict["Calibrated retention time finish"] + RT_tol
    )
elif RT_ref == "pred":
    Maxquant_result_dict["RT_search_left"] = (
        Maxquant_result_dict["predicted_RT"] - RT_tol
    )
    Maxquant_result_dict["RT_search_right"] = (
        Maxquant_result_dict["predicted_RT"] + RT_tol
    )
result_dict = process_scans_parallel(
    n_jobs=cpu_count(),
    # for small scale testing: MS1Scans.iloc[1000:1050, :]
    MS1Scans=MS1Scans.iloc[1000:1010, :],
    Maxquant_result=Maxquant_result_dict,
    preprocessing_method="raw",
    AbundanceMissingThres=0.5,
)
# Out:
# <module 'optimization.inference' from '/mnt/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/optimization/inference.py'>
# False
# 2023-11-15 13:05:51,097 - optimization.dictionary - INFO - Number of candidates by RT 4638
# 2023-11-15 13:05:51,157 - optimization.dictionary - INFO - Number of candidates after isotope match 1674
# 2023-11-15 13:05:51,158 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 636
# 2023-11-15 13:05:51,779 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 362
# 2023-11-15 13:05:51,781 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 388
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.2089985829642426e+17, tolerance: 415896198849370.4
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.1838026630971546e+17, tolerance: 415896198849370.4
#   model = cd_fast.enet_coordinate_descent_gram(
# 2023-11-15 13:05:51,908 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0 as best candidate!
# 2023-11-15 13:05:51,909 - optimization.inference - INFO - scan index 1000: activation successfully calculated with cosine distance 0.48717845145409056, RMSE 102507400.92886677.
# 2023-11-15 13:05:53,090 - optimization.dictionary - INFO - Number of candidates by RT 4628
# 2023-11-15 13:05:53,138 - optimization.dictionary - INFO - Number of candidates after isotope match 1644
# 2023-11-15 13:05:53,139 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 632
# 2023-11-15 13:05:53,722 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 374
# 2023-11-15 13:05:53,724 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 389
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.274175629421592e+17, tolerance: 439163941173351.9
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.245539450599436e+17, tolerance: 439163941173351.9
#   model = cd_fast.enet_coordinate_descent_gram(
# 2023-11-15 13:05:53,844 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.0001
# 2023-11-15 13:05:53,845 - optimization.inference - INFO - scan index 1001: activation successfully calculated with cosine distance 0.07764185967474868, RMSE 28034668.603182662.
# 2023-11-15 13:05:55,638 - optimization.dictionary - INFO - Number of candidates by RT 4645
# 2023-11-15 13:05:55,688 - optimization.dictionary - INFO - Number of candidates after isotope match 1618
# 2023-11-15 13:05:55,689 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 603
# 2023-11-15 13:05:56,280 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 307
# 2023-11-15 13:05:56,284 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 345
# 2023-11-15 13:05:56,461 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.001
# 2023-11-15 13:05:56,463 - optimization.inference - INFO - scan index 1002: activation successfully calculated with cosine distance 0.0548452032884128, RMSE 24776220.37873507.
# 2023-11-15 13:05:58,355 - optimization.dictionary - INFO - Number of candidates by RT 4646
# 2023-11-15 13:05:58,414 - optimization.dictionary - INFO - Number of candidates after isotope match 1694
# 2023-11-15 13:05:58,415 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 638
# 2023-11-15 13:05:59,100 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 338
# 2023-11-15 13:05:59,101 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 385
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.940943012818107e+17, tolerance: 405144475411063.3
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.940623215462119e+17, tolerance: 405144475411063.3
#   model = cd_fast.enet_coordinate_descent_gram(
# 2023-11-15 13:05:59,237 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0 as best candidate!
# 2023-11-15 13:05:59,238 - optimization.inference - INFO - scan index 1003: activation successfully calculated with cosine distance 0.3929259603085482, RMSE 61301136.563106276.
# 2023-11-15 13:06:00,583 - optimization.dictionary - INFO - Number of candidates by RT 4647
# 2023-11-15 13:06:00,641 - optimization.dictionary - INFO - Number of candidates after isotope match 1854
# 2023-11-15 13:06:00,642 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 701
# 2023-11-15 13:06:01,495 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 374
# 2023-11-15 13:06:01,498 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 413
# 2023-11-15 13:06:01,678 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.0001
# 2023-11-15 13:06:01,679 - optimization.inference - INFO - scan index 1004: activation successfully calculated with cosine distance 0.05562934826439003, RMSE 17901484.514427476.
# 2023-11-15 13:06:01,948 - optimization.dictionary - INFO - Number of candidates by RT 4665
# 2023-11-15 13:06:02,040 - optimization.dictionary - INFO - Number of candidates after isotope match 1812
# 2023-11-15 13:06:02,041 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 704
# 2023-11-15 13:06:02,943 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 386
# 2023-11-15 13:06:02,947 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 418
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.55673742458628e+17, tolerance: 257829855616601.72
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.553108100146013e+17, tolerance: 257829855616601.72
#   model = cd_fast.enet_coordinate_descent_gram(
# 2023-11-15 13:06:03,094 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.0001
# 2023-11-15 13:06:03,095 - optimization.inference - INFO - scan index 1005: activation successfully calculated with cosine distance 0.06233710626312883, RMSE 18172856.05877807.
# 2023-11-15 13:06:04,236 - optimization.dictionary - INFO - Number of candidates by RT 4664
# 2023-11-15 13:06:04,291 - optimization.dictionary - INFO - Number of candidates after isotope match 1836
# 2023-11-15 13:06:04,291 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 699
# 2023-11-15 13:06:05,069 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 348
# 2023-11-15 13:06:05,072 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 414
# 2023-11-15 13:06:05,256 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 1e-05 as best candidate!
# 2023-11-15 13:06:05,257 - optimization.inference - INFO - scan index 1006: activation successfully calculated with cosine distance 0.05438093758916085, RMSE 19347341.570727453.
# 2023-11-15 13:06:06,634 - optimization.dictionary - INFO - Number of candidates by RT 4657
# 2023-11-15 13:06:06,684 - optimization.dictionary - INFO - Number of candidates after isotope match 1776
# 2023-11-15 13:06:06,684 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 670
# 2023-11-15 13:06:07,433 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 349
# 2023-11-15 13:06:07,435 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 408
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7398514276965757e+17, tolerance: 468677757078966.3
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.7393917127951514e+17, tolerance: 468677757078966.3
#   model = cd_fast.enet_coordinate_descent_gram(
# 2023-11-15 13:06:07,538 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.0001
# 2023-11-15 13:06:07,539 - optimization.inference - INFO - scan index 1007: activation successfully calculated with cosine distance 0.03783955789242266, RMSE 19641479.019833285.
# 2023-11-15 13:06:07,831 - optimization.dictionary - INFO - Number of candidates by RT 4655
# 2023-11-15 13:06:07,884 - optimization.dictionary - INFO - Number of candidates after isotope match 1706
# 2023-11-15 13:06:07,884 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 632
# 2023-11-15 13:06:08,504 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 314
# 2023-11-15 13:06:08,506 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 354
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.6909179202601104e+17, tolerance: 505496150275691.3
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/zixuanxiao/miniconda3/envs/py310/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.689134249514041e+17, tolerance: 505496150275691.3
#   model = cd_fast.enet_coordinate_descent_gram(
# 2023-11-15 13:06:08,598 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0 as best candidate!
# 2023-11-15 13:06:08,599 - optimization.inference - INFO - scan index 1008: activation successfully calculated with cosine distance 0.2819474656590566, RMSE 88496019.87661697.
# 2023-11-15 13:06:09,755 - optimization.dictionary - INFO - Number of candidates by RT 4659
# 2023-11-15 13:06:09,807 - optimization.dictionary - INFO - Number of candidates after isotope match 1800
# 2023-11-15 13:06:09,808 - optimization.dictionary - INFO - Number of candidates after isotope abundance filter 650
# 2023-11-15 13:06:10,426 - optimization.dictionary - INFO - Number of candidate pairs with correlation larger than 0.95: 325
# 2023-11-15 13:06:10,427 - optimization.dictionary - INFO - Number of candidated involved in high correlation: 363
# 2023-11-15 13:06:10,513 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.0001
# 2023-11-15 13:06:10,514 - optimization.inference - INFO - scan index 1009: activation successfully calculated with cosine distance 0.04002929867183491, RMSE 17325264.927253135.

# %%
# merge results
n_precursors = Maxquant_result_dict.shape[0]
n_ms1scans = MS1Scans.shape[0]
activation = pd.DataFrame(
    index=Maxquant_result_dict["id"], columns=range(len(result_dict))
)
scan_record_list = []
# scan_alignments = {}
for scan_idx, result_dict_scan in result_dict.items():
    if result_dict_scan["activation"] is not None:
        activation.loc[
            result_dict_scan["activation"]["precursor"], scan_idx
        ] = result_dict_scan["activation"]["activation"]
    scan_record_list.append(result_dict_scan["scans_record"])
    # scan_alignments[scan_idx] = result_dict_scan['alignment']
scan_record = pd.DataFrame(
    scan_record_list,
    columns=[
        "Scan",
        "Time",
        "CandidatePrecursorByRT",
        "FilteredPrecursor",
        "NumberHighlyCorrDictCandidate",
        "BestAlpha",
        "Cosine Dist",
        "IntensityExplained",
    ],
)

# %%
n_precursors = Maxquant_result_dict.shape[0]
n_ms1scans = MS1Scans.shape[0]
activation = np.zeros((n_precursors, n_ms1scans))
scan_record_list = []
scan_alignments = {}
for scan_idx, result_dict_scan in result_dict.items():
    if result_dict_scan["activation"] is not None:
        activation[
            result_dict_scan["activation"]["precursor"], scan_idx
        ] = result_dict_scan["activation"]["activation"]
    scan_record_list.append(result_dict_scan["scans_record"])
    scan_alignments[scan_idx] = result_dict_scan["alignment"]
scan_summary = pd.DataFrame(
    scan_record_list,
    columns=[
        "Scan",
        "Time",
        "CandidatePrecursorByRT",
        "FilteredPrecursor",
        "NumberHighlyCorrDictCandidate",
        "BestAlpha",
        "Cosine Dist",
        "IntensityExplained",
    ],
)

# %%
from result_analysis.result_analysis import GenerateResultReport
import result_analysis.result_analysis

reload(result_analysis.result_analysis)
scan_record_processed = GenerateResultReport(
    scan_record=scan_summary, intensity_cols=[Maxquant_result_dict["Intensity"]]
)
# Out:
# <module 'result_analysis.result_analysis' from '/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/result_analysis/result_analysis.py'>
# -------------- Intensity -----------------
# Non zero intensity in Intensity = 16871
# --------------Empty Scans-----------------
# -------------- Time_EmptyScans -----------------
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Time, dtype: float64
# -------------- n_CandidateByRT_EmptyScans -----------------
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: n_CandidateByRT, dtype: float64
# -------------- n_filteredCandidate_EmptyScans -----------------
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: n_filteredCandidate, dtype: float64
# -------------- preservedRatio_IE_filter_EmptyScans -----------------
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: preservedRatio_IE_filter, dtype: float64
# --------------Non Empty Scans-----------------
# Column  Loss does not exist!
# -------------- Cosine Dist_nonEmptyScans -----------------
# count    50.000000
# mean      0.339294
# std       0.142615
# min       0.029804
# 25%       0.251347
# 50%       0.354333
# 75%       0.475052
# max       0.545030
# Name: Cosine Dist, dtype: float64
# -------------- n_CandidateByRT_nonEmptyScans -----------------
# count     50.00000
# mean     519.00000
# std       10.84774
# min      497.00000
# 25%      512.50000
# 50%      522.50000
# 75%      525.00000
# max      539.00000
# Name: n_CandidateByRT, dtype: float64
# -------------- n_filteredCandidate_nonEmptyScans -----------------
# count     50.000000
# mean     115.980000
# std       12.329639
# min       90.000000
# 25%      106.000000
# 50%      115.500000
# 75%      125.750000
# max      138.000000
# Name: n_filteredCandidate, dtype: float64
# -------------- preservedRatio_IE_filter_nonEmptyScans -----------------
# count    50.000000
# mean      0.223539
# std       0.023831
# min       0.172414
# 25%       0.203254
# 50%       0.223815
# 75%       0.242093
# max       0.262857
# Name: preservedRatio_IE_filter, dtype: float64
# -------------- IntensityExplained_nonEmptyScans -----------------
# count    50.000000
# mean      0.328392
# std       0.127209
# min       0.147827
# 25%       0.220380
# 50%       0.271403
# 75%       0.453005
# max       0.586139
# Name: IntensityExplained, dtype: float64
# Column  PeaksExplained does not exist!

# %%
from optimization.inference import process_scans
import optimization.inference

reload(optimization.inference)

result_dict = process_scans(
    MS1Scans=MS1Scans.iloc[600:610, :], Maxquant_result=Maxquant_result_dict
)
# Out:
# <module 'optimization.inference' from '/cmnfs/proj/ORIGINS/protMSD/maxquant/ScanByScan/optimization/inference.py'>
# 2023-11-06 13:53:33,942 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:33,945 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:33,946 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.0005284012636698199
# 2023-11-06 13:53:33,947 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:33,950 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:33,951 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:33,952 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:33,954 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:33,955 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:33,957 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:33,959 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:33,960 - optimization.inference - DEBUG - Alpha = 0.01, tol = -6.661338147750939e-16
# 2023-11-06 13:53:33,960 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:33,961 - root - DEBUG - scan index 600: activation successfully calculated with cosine distance 0.9567519977499264.
# 2023-11-06 13:53:35,235 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:35,238 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:35,239 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.00038633134531051994
# 2023-11-06 13:53:35,240 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:35,242 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:35,243 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:35,244 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:35,246 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:35,247 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:35,248 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:35,250 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:35,251 - optimization.inference - DEBUG - Alpha = 0.01, tol = -2.220446049250313e-16
# 2023-11-06 13:53:35,251 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:35,252 - root - DEBUG - scan index 601: activation successfully calculated with cosine distance 0.9527632748734853.
# 2023-11-06 13:53:36,505 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:36,508 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:36,509 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.00046101164255252236
# 2023-11-06 13:53:36,509 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:36,512 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:36,512 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 1.1102230246251565e-16
# 2023-11-06 13:53:36,513 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.0001
# 2023-11-06 13:53:36,515 - root - DEBUG - scan index 602: activation successfully calculated with cosine distance 0.9547866070173849.
# 2023-11-06 13:53:37,784 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:37,786 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:37,787 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.00045938269466849757
# 2023-11-06 13:53:37,788 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:37,790 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:37,791 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:37,792 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:37,794 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:37,795 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:37,796 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:37,797 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:37,798 - optimization.inference - DEBUG - Alpha = 0.01, tol = -2.220446049250313e-16
# 2023-11-06 13:53:37,798 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:37,799 - root - DEBUG - scan index 603: activation successfully calculated with cosine distance 0.9555196241901985.
# 2023-11-06 13:53:39,067 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:39,069 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:39,070 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.0003923161168405409
# 2023-11-06 13:53:39,071 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:39,073 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:39,074 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:39,075 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:39,078 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:39,078 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:39,079 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:39,081 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:39,082 - optimization.inference - DEBUG - Alpha = 0.01, tol = -2.220446049250313e-16
# 2023-11-06 13:53:39,082 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:39,083 - root - DEBUG - scan index 604: activation successfully calculated with cosine distance 0.9332595002993213.
# 2023-11-06 13:53:40,342 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:40,344 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:40,345 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.0003328438502017139
# 2023-11-06 13:53:40,346 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:40,349 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:40,350 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:40,351 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:40,353 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:40,353 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:40,354 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:40,355 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:40,356 - optimization.inference - DEBUG - Alpha = 0.01, tol = -1.1102230246251565e-16
# 2023-11-06 13:53:40,356 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:40,357 - root - DEBUG - scan index 605: activation successfully calculated with cosine distance 0.9298272052914.
# 2023-11-06 13:53:43,441 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:43,443 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:43,444 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.0003746648918108164
# 2023-11-06 13:53:43,445 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:43,448 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:43,448 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:43,449 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:43,451 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:43,452 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:43,453 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:43,455 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:43,456 - optimization.inference - DEBUG - Alpha = 0.01, tol = -2.220446049250313e-16
# 2023-11-06 13:53:43,457 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:43,457 - root - DEBUG - scan index 606: activation successfully calculated with cosine distance 0.931414249310386.
# 2023-11-06 13:53:44,708 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:44,711 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:44,712 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.000150724431139726
# 2023-11-06 13:53:44,713 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:44,714 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:44,715 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:44,716 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:44,718 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:44,719 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:44,720 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:44,722 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:44,723 - optimization.inference - DEBUG - Alpha = 0.01, tol = -4.440892098500626e-16
# 2023-11-06 13:53:44,724 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:44,724 - root - DEBUG - scan index 607: activation successfully calculated with cosine distance 0.9273558249295232.
# 2023-11-06 13:53:45,988 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:45,991 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:45,991 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.0002582372276149769
# 2023-11-06 13:53:45,992 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:45,994 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:45,994 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 1.1102230246251565e-16
# 2023-11-06 13:53:45,995 - optimization.inference - INFO - Reached convergence criteria at alpha = 0.0001
# 2023-11-06 13:53:45,996 - root - DEBUG - scan index 608: activation successfully calculated with cosine distance 0.9289364617911825.
# 2023-11-06 13:53:47,323 - optimization.inference - DEBUG - Current alpha = 1e-05
# 2023-11-06 13:53:47,325 - optimization.inference - DEBUG - Alpha list [0, 1e-05]
# 2023-11-06 13:53:47,326 - optimization.inference - DEBUG - Alpha = 1e-05, tol = 0.0009559230699315302
# 2023-11-06 13:53:47,327 - optimization.inference - DEBUG - Current alpha = 0.0001
# 2023-11-06 13:53:47,330 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001]
# 2023-11-06 13:53:47,330 - optimization.inference - DEBUG - Alpha = 0.0001, tol = 0.0
# 2023-11-06 13:53:47,332 - optimization.inference - DEBUG - Current alpha = 0.001
# 2023-11-06 13:53:47,334 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001]
# 2023-11-06 13:53:47,335 - optimization.inference - DEBUG - Alpha = 0.001, tol = 0.0
# 2023-11-06 13:53:47,335 - optimization.inference - DEBUG - Current alpha = 0.01
# 2023-11-06 13:53:47,337 - optimization.inference - DEBUG - Alpha list [0, 1e-05, 0.0001, 0.001, 0.01]
# 2023-11-06 13:53:47,338 - optimization.inference - DEBUG - Alpha = 0.01, tol = -2.220446049250313e-16
# 2023-11-06 13:53:47,339 - optimization.inference - WARNING - Increasing cosine distance! Using previous alpha = 0.0001 as best candidate!
# 2023-11-06 13:53:47,340 - root - DEBUG - scan index 609: activation successfully calculated with cosine distance 0.8920475988237093.

# %%
n_precursors = Maxquant_result_dict.shape[0]
n_ms1scans = MS1Scans.shape[0]
activation = np.zeros((n_precursors, n_ms1scans))
loss = []
empty_scans = []
ScanProcessRecords = {}
for scan_idx, OneScan in MS1Scans.iterrows():  # scan by scan activation
    CandidatePrecursorsByRT = Maxquant_result_dict.loc[
        (
            Maxquant_result_dict["Calibrated retention time start"] - RT_tol
            <= OneScan["starttime"]
        )
        & (
            Maxquant_result_dict["Calibrated retention time finish"] + RT_tol
            >= OneScan["starttime"]
        )
    ]
    if CandidatePrecursorsByRT.shape[0] > 0:
        (
            CandidateDict,
            CandidatePrecursorsByRT,
            alignment,
            IsotopeNotObs,
            y_true,
            peak_results,
        ) = ConstructDict(CandidatePrecursorsByRT, OneScan, method="peakRange")
        filteredPrecursorIdx = np.array(CandidateDict.columns[1:], dtype=int)
        if CandidateDict.shape[1] > 1:
            (
                activationByScan,
                lossByScan,
                scoreByScan,
                pred,
                explainedInt,
                explainedPeaks,
            ) = CalcPrecursorQuant(
                CandidateDict,
                y_true,
                filteredPrecursorIdx=filteredPrecursorIdx,
                alpha=alpha,
            )
            activation[filteredPrecursorIdx, scan_idx] = activationByScan
            loss.append(lossByScan)
            score.append(scoreByScan)
            RA.PlotTrueAndPredict(
                x=CandidateDict.index,
                prediction=pred,
                true=y_true["intensity"],
                log=True,
            )
        else:
            lossByScan = None
            print(
                "Scan number, start time ",
                scan_idx,
                OneScan["starttime"],
                "does not have valid candidate.",
            )
            empty_scans.append((scan_idx, OneScan["starttime"]))
        ScanProcessRecords[scan_idx] = {
            "CandidatePrecursorIdx": CandidatePrecursorsByRT.index,
            "FilteredCandidatePrecursor": filteredPrecursorIdx,
            "Residue": lossByScan,
            "alignment": alignment,
        }
    else:
        print(
            "Scan number, start time ",
            scan_idx,
            OneScan["starttime"],
            "does not have valid candidate.",
        )

# %%
empty_scans = pd.DataFrame(empty_scans, columns=["Scan", "Time"])

# %%
tmp = activation[:, 2400:2500]
a = tmp.sum(axis=1)
np.array(a > 0).sum()

# %%
activationSumByScan = activation.sum(axis=0)
np.array(activationSumByScan > 0).sum()

# %%
activationSumByPrecursor = activation.sum(axis=1)
np.array(activationSumByPrecursor > 0).sum()

# %%
Intensity_comparison = pd.DataFrame(
    {"MQ_int": Maxquant_result_dict["Intensity"], "Inf_int": activationSumByPrecursor}
)
Intensity_comparison = Intensity_comparison[
    Intensity_comparison["Inf_int"] > 0
].dropna()

# %%
np.save(output_file + "_activationByScanFromLasso.npy", activation)

# %%
import matplotlib.pyplot as plt

plt.scatter(x=range(1650, 1700), y=activation[17754, 1650:1700])
